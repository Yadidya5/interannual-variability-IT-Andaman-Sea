# %% [markdown]
# <a href="https://colab.research.google.com/github/Yadidya5/interannual-variability-IT-Andaman-Sea/blob/main/TPXO9_barotropic_baroclinic_IT_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Extract Barotropic tide from TPXO9**

# %%
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import xgcm as xg
#========================================================
import sys
sys.path.append('py_scripts')
import yadi
#========================================================

# %% [markdown]
# Open OTPS folder for barotropic tide extraction

# %%
# %cd models/2_OTPS/OTPSnc
# Out:
# [WinError 3] The system cannot find the path specified: 'models/2_OTPS/OTPSnc'
# C:\Users\Yadidya\OneDrive - IIT Delhi\delhi\models\2_OTPS\OTPSnc
# 'C:\\Users\\Yadidya\\OneDrive - IIT Delhi\\delhi\\models\\2_OTPS\\OTPSnc'

# %% [markdown]
# Open the "Interannual folder"

# %%
# %cd ../../../papers_internal_waves/interannual/brotropic_tide_extract/
# Out:
# C:\Users\Yadidya\OneDrive - IIT Delhi\delhi\papers_internal_waves\interannual\brotropic_tide_extract

# %%
bd12=xr.open_dataset("../../../data/BD12profiledata/bd12_tsuv_mar2012_jul2019.nc")
bd12
# Out:
# <xarray.Dataset>
# Dimensions:  (dep1: 11, dep2: 42, time: 64941)
# Coordinates:
#   * dep1     (dep1) int64 1 5 10 15 20 30 50 75 100 200 500
#   * dep2     (dep2) int64 1 10 15 20 25 30 35 40 ... 180 185 190 195 200 205 210
#   * time     (time) datetime64[ns] 2012-03-01 ... 2019-07-28T20:00:00
# Data variables:
#     temp     (time, dep1) float64 ...
#     salt     (time, dep1) float64 ...
#     uvel     (time, dep2) float64 ...
#     vvel     (time, dep2) float64 ...
# Attributes:
#     Date created:  12-Nov-2020

# %%
fig, ax = plt.subplots(figsize=(20,7))

bd12.vvel.plot(y='dep2',yincrease=False,levels=np.arange(-100,100,10))
#bd12.vvel[:,22].plot()

# %% [markdown]
# 18-12-2020 5:55 AM \
# Found that there's a lot of missing data in currents. \
# So probably there's no point in computing Barotropic tide after all.\
# Therefore, the only option that I probably have to study the interannual variability studies is to do using Stratification data. \

# %%
fig, ax = plt.subplots(figsize=(20,7))

bd12.salt.plot(y='dep1',yincrease=False,levels=np.arange(31,37,0.5))
