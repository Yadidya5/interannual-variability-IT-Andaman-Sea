# %% [markdown]
# <a href="https://colab.research.google.com/github/Yadidya5/interannual-variability-IT-Andaman-Sea/blob/main/TPXO9_barotropic_baroclinic_IT_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Extract Barotropic tide from TPXO9**

# %%
import numpy as np
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import xgcm as xg
#========================================================
import sys
sys.path.append('py_scripts')
import yadi
#========================================================

# %%
# %cd models/2_OTPS/OTPSnc
# Out:
# C:\Users\Yadidya\OneDrive - IIT Delhi\delhi\models\2_OTPS\OTPSnc

# %%
# %pwd
# Out:
# 'C:\\Users\\Yadidya\\OneDrive - IIT Delhi\\delhi\\models\\2_OTPS\\OTPSnc'
